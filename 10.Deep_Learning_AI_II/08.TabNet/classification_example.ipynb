# %%
import time

# %%
start = time.time()

# %%
# !pip install pytorch_tabnet
# Out:
# Collecting pytorch_tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.0.2)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.6.1)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.14.1)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3->pytorch_tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->pytorch_tabnet) (3.0.2)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 3.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 32.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch_tabnet
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch_tabnet-4.1.0

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=e466319e001cb86b7814ebc900eabde65b37f14c687aa57f18da1d9a0071583f
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score

import pandas as pd
import numpy as np
np.random.seed(0)

import scipy

import os
import wget
from pathlib import Path

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = f"1"

# %%
import torch
torch.__version__
# Out:
# '2.6.0+cu124'

# %% [markdown]
# # Download census-income dataset

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
dataset_name = 'census-income'
out = Path(os.getcwd()+'/data/'+dataset_name+'.csv')

# %%
out.parent.mkdir(parents=True, exist_ok=True)
if out.exists():
    print("File already exists.")
else:
    print("Downloading file...")
    wget.download(url, out.as_posix())
# Out:
# Downloading file...

# %% [markdown]
# # Load data and split

# %%
train = pd.read_csv(out)
target = ' <=50K'
if "Set" not in train.columns:
    train["Set"] = np.random.choice(["train", "valid", "test"], p =[.8, .1, .1], size=(train.shape[0],))

train_indices = train[train.Set=="train"].index
valid_indices = train[train.Set=="valid"].index
test_indices = train[train.Set=="test"].index

# %% [markdown]
# # Simple preprocessing
#
# Label encode categorical features and fill empty cells.

# %%
nunique = train.nunique()
types = train.dtypes

categorical_columns = []
categorical_dims =  {}
for col in train.columns:
    if types[col] == 'object' or nunique[col] < 200:
        print(col, train[col].nunique())
        l_enc = LabelEncoder()
        train[col] = train[col].fillna("VV_likely")
        train[col] = l_enc.fit_transform(train[col].values)
        categorical_columns.append(col)
        categorical_dims[col] = len(l_enc.classes_)
    else:
        train.fillna(train.loc[train_indices, col].mean(), inplace=True)
# Out:
# 39 73
#  State-gov 9
#  Bachelors 16
#  13 16
#  Never-married 7
#  Adm-clerical 15
#  Not-in-family 6
#  White 5
#  Male 2
#  2174 119
#  0 92
#  40 94
#  United-States 42
#  <=50K 2
# Set 3

# %%
# check that pipeline accepts strings
train.loc[train[target]==0, target] = "wealthy"
train.loc[train[target]==1, target] = "not_wealthy"
# Out:
# <ipython-input-12-b107fcde6490>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'wealthy' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train.loc[train[target]==0, target] = "wealthy"

# %% [markdown]
# # Define categorical features for categorical embeddings

# %%
unused_feat = ['Set']

features = [ col for col in train.columns if col not in unused_feat+[target]]

cat_idxs = [ i for i, f in enumerate(features) if f in categorical_columns]

cat_dims = [ categorical_dims[f] for i, f in enumerate(features) if f in categorical_columns]

# %% [markdown]
# # Grouped features
#
# You can now specify groups of feature which will share a common attention.
#
# This may be very usefull for features comming from a same preprocessing technique like PCA for example.

# %%
len(features)
# Out:
# 14

# %%
grouped_features = [[0, 1, 2], [8, 9, 10]]

# %% [markdown]
# # Network parameters

# %%
tabnet_params = {"cat_idxs":cat_idxs,
                 "cat_dims":cat_dims,
                 "cat_emb_dim":2,
                 "optimizer_fn":torch.optim.Adam,
                 "optimizer_params":dict(lr=2e-2),
                 "scheduler_params":{"step_size":50, # how to use learning rate scheduler
                                 "gamma":0.9},
                 "scheduler_fn":torch.optim.lr_scheduler.StepLR,
                 "mask_type":'entmax', # "sparsemax"
                 "grouped_features" : grouped_features
                }

clf = TabNetClassifier(**tabnet_params
                      )
# Out:
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %% [markdown]
# # Training

# %%
X_train = train[features].values[train_indices]
y_train = train[target].values[train_indices]

X_valid = train[features].values[valid_indices]
y_valid = train[target].values[valid_indices]

X_test = train[features].values[test_indices]
y_test = train[target].values[test_indices]

# %%
max_epochs = 50 if not os.getenv("CI", False) else 2

# %%
from pytorch_tabnet.augmentations import ClassificationSMOTE
aug = ClassificationSMOTE(p=0.2)

# %%
# This illustrates the behaviour of the model's fit method using Compressed Sparse Row matrices
sparse_X_train = scipy.sparse.csr_matrix(X_train)  # Create a CSR matrix from X_train
sparse_X_valid = scipy.sparse.csr_matrix(X_valid)  # Create a CSR matrix from X_valid

# Fitting the model
clf.fit(
    X_train=sparse_X_train, y_train=y_train,
    eval_set=[(sparse_X_train, y_train), (sparse_X_valid, y_valid)],
    eval_name=['train', 'valid'],
    eval_metric=['auc'],
    max_epochs=max_epochs , patience=20,
    batch_size=1024, virtual_batch_size=128,
    num_workers=0,
    weights=1,
    drop_last=False,
    augmentations=aug, #aug, None
)
# Out:
# epoch 0  | loss: 0.58039 | train_auc: 0.81603 | valid_auc: 0.82541 |  0:00:07s
# epoch 1  | loss: 0.47431 | train_auc: 0.86123 | valid_auc: 0.86594 |  0:00:12s
# epoch 2  | loss: 0.45242 | train_auc: 0.88246 | valid_auc: 0.88437 |  0:00:18s
# epoch 3  | loss: 0.43115 | train_auc: 0.89496 | valid_auc: 0.8941  |  0:00:24s
# epoch 4  | loss: 0.42419 | train_auc: 0.90402 | valid_auc: 0.9033  |  0:00:29s
# epoch 5  | loss: 0.41078 | train_auc: 0.90977 | valid_auc: 0.91151 |  0:00:34s
# epoch 6  | loss: 0.39628 | train_auc: 0.91397 | valid_auc: 0.91681 |  0:00:39s
# epoch 7  | loss: 0.39185 | train_auc: 0.91789 | valid_auc: 0.9221  |  0:00:45s
# epoch 8  | loss: 0.3884  | train_auc: 0.92078 | valid_auc: 0.92504 |  0:00:50s
# epoch 9  | loss: 0.38239 | train_auc: 0.92131 | valid_auc: 0.92382 |  0:00:55s
# epoch 10 | loss: 0.37835 | train_auc: 0.92278 | valid_auc: 0.92278 |  0:01:01s
# epoch 11 | loss: 0.37798 | train_auc: 0.926   | valid_auc: 0.92547 |  0:01:06s
# epoch 12 | loss: 0.37593 | train_auc: 0.92697 | valid_auc: 0.92635 |  0:01:12s
# epoch 13 | loss: 0.36354 | train_auc: 0.92665 | valid_auc: 0.92803 |  0:01:17s
# epoch 14 | loss: 0.36719 | train_auc: 0.92853 | valid_auc: 0.92573 |  0:01:23s
# epoch 15 | loss: 0.36773 | train_auc: 0.92947 | valid_auc: 0.92601 |  0:01:29s
# epoch 16 | loss: 0.35922 | train_auc: 0.92965 | valid_auc: 0.92726 |  0:01:35s
# epoch 17 | loss: 0.3629  | train_auc: 0.93076 | valid_auc: 0.92789 |  0:01:40s
# epoch 18 | loss: 0.36588 | train_auc: 0.93158 | valid_auc: 0.92813 |  0:01:45s
# epoch 19 | loss: 0.36606 | train_auc: 0.93175 | valid_auc: 0.9277  |  0:01:51s
# epoch 20 | loss: 0.36084 | train_auc: 0.93214 | valid_auc: 0.92787 |  0:01:56s
# epoch 21 | loss: 0.35925 | train_auc: 0.9327  | valid_auc: 0.9274  |  0:02:01s
# epoch 22 | loss: 0.35809 | train_auc: 0.93349 | valid_auc: 0.9279  |  0:02:07s
# epoch 23 | loss: 0.36347 | train_auc: 0.935   | valid_auc: 0.92762 |  0:02:13s
# epoch 24 | loss: 0.3574  | train_auc: 0.93503 | valid_auc: 0.92718 |  0:02:18s
# epoch 25 | loss: 0.35662 | train_auc: 0.93494 | valid_auc: 0.92735 |  0:02:23s
# epoch 26 | loss: 0.35422 | train_auc: 0.93577 | valid_auc: 0.92946 |  0:02:29s
# epoch 27 | loss: 0.35768 | train_auc: 0.9352  | valid_auc: 0.92861 |  0:02:34s
# epoch 28 | loss: 0.35787 | train_auc: 0.93504 | valid_auc: 0.9302  |  0:02:40s
# epoch 29 | loss: 0.3569  | train_auc: 0.93601 | valid_auc: 0.9307  |  0:02:45s
# epoch 30 | loss: 0.35478 | train_auc: 0.93645 | valid_auc: 0.92846 |  0:02:51s
# epoch 31 | loss: 0.35714 | train_auc: 0.93707 | valid_auc: 0.92878 |  0:02:56s
# epoch 32 | loss: 0.3508  | train_auc: 0.93707 | valid_auc: 0.92726 |  0:03:02s
# epoch 33 | loss: 0.35095 | train_auc: 0.93713 | valid_auc: 0.92728 |  0:03:07s
# epoch 34 | loss: 0.35306 | train_auc: 0.93729 | valid_auc: 0.92786 |  0:03:13s
# epoch 35 | loss: 0.3509  | train_auc: 0.93818 | valid_auc: 0.92784 |  0:03:18s
# epoch 36 | loss: 0.3502  | train_auc: 0.93777 | valid_auc: 0.92787 |  0:03:23s
# epoch 37 | loss: 0.35226 | train_auc: 0.93787 | valid_auc: 0.92712 |  0:03:29s
# epoch 38 | loss: 0.35518 | train_auc: 0.93786 | valid_auc: 0.92712 |  0:03:34s
# epoch 39 | loss: 0.34995 | train_auc: 0.93797 | valid_auc: 0.92713 |  0:03:40s
# epoch 40 | loss: 0.34621 | train_auc: 0.93842 | valid_auc: 0.92706 |  0:03:45s
# epoch 41 | loss: 0.34746 | train_auc: 0.93921 | valid_auc: 0.92486 |  0:03:51s
# epoch 42 | loss: 0.35166 | train_auc: 0.93817 | valid_auc: 0.92652 |  0:03:56s
# epoch 43 | loss: 0.35697 | train_auc: 0.93905 | valid_auc: 0.92719 |  0:04:01s
# epoch 44 | loss: 0.34486 | train_auc: 0.94048 | valid_auc: 0.92658 |  0:04:06s
# epoch 45 | loss: 0.34847 | train_auc: 0.9409  | valid_auc: 0.92708 |  0:04:12s
# epoch 46 | loss: 0.34568 | train_auc: 0.93984 | valid_auc: 0.92447 |  0:04:17s
# epoch 47 | loss: 0.34489 | train_auc: 0.94077 | valid_auc: 0.92726 |  0:04:23s
# epoch 48 | loss: 0.35039 | train_auc: 0.93991 | valid_auc: 0.92418 |  0:04:29s
# epoch 49 | loss: 0.33447 | train_auc: 0.94086 | valid_auc: 0.9243  |  0:04:34s
#
# Early stopping occurred at epoch 49 with best_epoch = 29 and best_valid_auc = 0.9307
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
# This illustrates the warm_start=False behaviour
save_history = []

# Fitting the model without starting from a warm start nor computing the feature importance
for _ in range(2):
    clf.fit(
        X_train=X_train, y_train=y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        eval_name=['train', 'valid'],
        eval_metric=['auc'],
        max_epochs=max_epochs , patience=20,
        batch_size=1024, virtual_batch_size=128,
        num_workers=0,
        weights=1,
        drop_last=False,
        augmentations=aug, #aug, None
        compute_importance=False
    )
    save_history.append(clf.history["valid_auc"])

assert(np.all(np.array(save_history[0]==np.array(save_history[1]))))

save_history = []  # Resetting the list to show that it also works when computing feature importance

# Fitting the model without starting from a warm start but with the computing of the feature importance activated
for _ in range(2):
    clf.fit(
        X_train=X_train, y_train=y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        eval_name=['train', 'valid'],
        eval_metric=['auc'],
        max_epochs=max_epochs , patience=20,
        batch_size=1024, virtual_batch_size=128,
        num_workers=0,
        weights=1,
        drop_last=False,
        augmentations=aug, #aug, None
        compute_importance=True # True by default so not needed
    )
    save_history.append(clf.history["valid_auc"])

assert(np.all(np.array(save_history[0]==np.array(save_history[1]))))
# Out:
# epoch 0  | loss: 0.58039 | train_auc: 0.81603 | valid_auc: 0.82541 |  0:00:02s
# epoch 1  | loss: 0.47431 | train_auc: 0.86123 | valid_auc: 0.86594 |  0:00:03s
# epoch 2  | loss: 0.45242 | train_auc: 0.88246 | valid_auc: 0.88437 |  0:00:05s
# epoch 3  | loss: 0.43115 | train_auc: 0.89496 | valid_auc: 0.8941  |  0:00:07s
# epoch 4  | loss: 0.42419 | train_auc: 0.90402 | valid_auc: 0.9033  |  0:00:09s
# epoch 5  | loss: 0.41078 | train_auc: 0.90977 | valid_auc: 0.91151 |  0:00:11s
# epoch 6  | loss: 0.39628 | train_auc: 0.91397 | valid_auc: 0.91681 |  0:00:13s
# epoch 7  | loss: 0.39185 | train_auc: 0.91789 | valid_auc: 0.9221  |  0:00:15s
# epoch 8  | loss: 0.3884  | train_auc: 0.92078 | valid_auc: 0.92504 |  0:00:17s
# epoch 9  | loss: 0.38239 | train_auc: 0.92131 | valid_auc: 0.92382 |  0:00:18s
# epoch 10 | loss: 0.37835 | train_auc: 0.92278 | valid_auc: 0.92278 |  0:00:20s
# epoch 11 | loss: 0.37798 | train_auc: 0.926   | valid_auc: 0.92547 |  0:00:22s
# epoch 12 | loss: 0.37593 | train_auc: 0.92697 | valid_auc: 0.92635 |  0:00:24s
# epoch 13 | loss: 0.36354 | train_auc: 0.92665 | valid_auc: 0.92803 |  0:00:26s
# epoch 14 | loss: 0.36719 | train_auc: 0.92853 | valid_auc: 0.92573 |  0:00:28s
# epoch 15 | loss: 0.36773 | train_auc: 0.92947 | valid_auc: 0.92601 |  0:00:30s
# epoch 16 | loss: 0.35922 | train_auc: 0.92965 | valid_auc: 0.92726 |  0:00:32s
# epoch 17 | loss: 0.3629  | train_auc: 0.93076 | valid_auc: 0.92789 |  0:00:33s
# epoch 18 | loss: 0.36588 | train_auc: 0.93158 | valid_auc: 0.92813 |  0:00:35s
# epoch 19 | loss: 0.36606 | train_auc: 0.93175 | valid_auc: 0.9277  |  0:00:38s
# epoch 20 | loss: 0.36084 | train_auc: 0.93214 | valid_auc: 0.92787 |  0:00:39s
# epoch 21 | loss: 0.35925 | train_auc: 0.9327  | valid_auc: 0.9274  |  0:00:41s
# epoch 22 | loss: 0.35809 | train_auc: 0.93349 | valid_auc: 0.9279  |  0:00:43s
# epoch 23 | loss: 0.36347 | train_auc: 0.935   | valid_auc: 0.92762 |  0:00:45s
# epoch 24 | loss: 0.3574  | train_auc: 0.93503 | valid_auc: 0.92718 |  0:00:46s
# epoch 25 | loss: 0.35662 | train_auc: 0.93494 | valid_auc: 0.92735 |  0:00:49s
# epoch 26 | loss: 0.35422 | train_auc: 0.93577 | valid_auc: 0.92946 |  0:00:51s
# epoch 27 | loss: 0.35768 | train_auc: 0.9352  | valid_auc: 0.92861 |  0:00:53s
# epoch 28 | loss: 0.35787 | train_auc: 0.93504 | valid_auc: 0.9302  |  0:00:54s
# epoch 29 | loss: 0.3569  | train_auc: 0.93601 | valid_auc: 0.9307  |  0:00:56s
# epoch 30 | loss: 0.35478 | train_auc: 0.93645 | valid_auc: 0.92846 |  0:00:58s
# epoch 31 | loss: 0.35714 | train_auc: 0.93707 | valid_auc: 0.92878 |  0:01:00s
# epoch 32 | loss: 0.3508  | train_auc: 0.93707 | valid_auc: 0.92726 |  0:01:02s
# epoch 33 | loss: 0.35095 | train_auc: 0.93713 | valid_auc: 0.92728 |  0:01:04s
# epoch 34 | loss: 0.35306 | train_auc: 0.93729 | valid_auc: 0.92786 |  0:01:06s
# epoch 35 | loss: 0.3509  | train_auc: 0.93818 | valid_auc: 0.92784 |  0:01:07s
# epoch 36 | loss: 0.3502  | train_auc: 0.93777 | valid_auc: 0.92787 |  0:01:09s
# epoch 37 | loss: 0.35226 | train_auc: 0.93787 | valid_auc: 0.92712 |  0:01:11s
# epoch 38 | loss: 0.35518 | train_auc: 0.93786 | valid_auc: 0.92712 |  0:01:13s
# epoch 39 | loss: 0.34995 | train_auc: 0.93797 | valid_auc: 0.92713 |  0:01:15s
# epoch 40 | loss: 0.34621 | train_auc: 0.93842 | valid_auc: 0.92706 |  0:01:17s
# epoch 41 | loss: 0.34746 | train_auc: 0.93921 | valid_auc: 0.92486 |  0:01:19s
# epoch 42 | loss: 0.35166 | train_auc: 0.93817 | valid_auc: 0.92652 |  0:01:21s
# epoch 43 | loss: 0.35697 | train_auc: 0.93905 | valid_auc: 0.92719 |  0:01:22s
# epoch 44 | loss: 0.34486 | train_auc: 0.94048 | valid_auc: 0.92658 |  0:01:24s
# epoch 45 | loss: 0.34847 | train_auc: 0.9409  | valid_auc: 0.92708 |  0:01:27s
# epoch 46 | loss: 0.34568 | train_auc: 0.93984 | valid_auc: 0.92447 |  0:01:29s
# epoch 47 | loss: 0.34489 | train_auc: 0.94077 | valid_auc: 0.92726 |  0:01:30s
# epoch 48 | loss: 0.35039 | train_auc: 0.93991 | valid_auc: 0.92418 |  0:01:32s
# epoch 49 | loss: 0.33447 | train_auc: 0.94086 | valid_auc: 0.9243  |  0:01:34s
#
# Early stopping occurred at epoch 49 with best_epoch = 29 and best_valid_auc = 0.9307
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 0.58039 | train_auc: 0.81603 | valid_auc: 0.82541 |  0:00:01s
# epoch 1  | loss: 0.47431 | train_auc: 0.86123 | valid_auc: 0.86594 |  0:00:04s
# epoch 2  | loss: 0.45242 | train_auc: 0.88246 | valid_auc: 0.88437 |  0:00:06s
# epoch 3  | loss: 0.43115 | train_auc: 0.89496 | valid_auc: 0.8941  |  0:00:07s
# epoch 4  | loss: 0.42419 | train_auc: 0.90402 | valid_auc: 0.9033  |  0:00:09s
# epoch 5  | loss: 0.41078 | train_auc: 0.90977 | valid_auc: 0.91151 |  0:00:11s
# epoch 6  | loss: 0.39628 | train_auc: 0.91397 | valid_auc: 0.91681 |  0:00:13s
# epoch 7  | loss: 0.39185 | train_auc: 0.91789 | valid_auc: 0.9221  |  0:00:15s
# epoch 8  | loss: 0.3884  | train_auc: 0.92078 | valid_auc: 0.92504 |  0:00:17s
# epoch 9  | loss: 0.38239 | train_auc: 0.92131 | valid_auc: 0.92382 |  0:00:19s
# epoch 10 | loss: 0.37835 | train_auc: 0.92278 | valid_auc: 0.92278 |  0:00:21s
# epoch 11 | loss: 0.37798 | train_auc: 0.926   | valid_auc: 0.92547 |  0:00:22s
# epoch 12 | loss: 0.37593 | train_auc: 0.92697 | valid_auc: 0.92635 |  0:00:24s
# epoch 13 | loss: 0.36354 | train_auc: 0.92665 | valid_auc: 0.92803 |  0:00:26s
# epoch 14 | loss: 0.36719 | train_auc: 0.92853 | valid_auc: 0.92573 |  0:00:28s
# epoch 15 | loss: 0.36773 | train_auc: 0.92947 | valid_auc: 0.92601 |  0:00:30s
# epoch 16 | loss: 0.35922 | train_auc: 0.92965 | valid_auc: 0.92726 |  0:00:32s
# epoch 17 | loss: 0.3629  | train_auc: 0.93076 | valid_auc: 0.92789 |  0:00:33s
# epoch 18 | loss: 0.36588 | train_auc: 0.93158 | valid_auc: 0.92813 |  0:00:35s
# epoch 19 | loss: 0.36606 | train_auc: 0.93175 | valid_auc: 0.9277  |  0:00:37s
# epoch 20 | loss: 0.36084 | train_auc: 0.93214 | valid_auc: 0.92787 |  0:00:39s
# epoch 21 | loss: 0.35925 | train_auc: 0.9327  | valid_auc: 0.9274  |  0:00:41s
# epoch 22 | loss: 0.35809 | train_auc: 0.93349 | valid_auc: 0.9279  |  0:00:43s
# epoch 23 | loss: 0.36347 | train_auc: 0.935   | valid_auc: 0.92762 |  0:00:45s
# epoch 24 | loss: 0.3574  | train_auc: 0.93503 | valid_auc: 0.92718 |  0:00:46s
# epoch 25 | loss: 0.35662 | train_auc: 0.93494 | valid_auc: 0.92735 |  0:00:48s
# epoch 26 | loss: 0.35422 | train_auc: 0.93577 | valid_auc: 0.92946 |  0:00:50s
# epoch 27 | loss: 0.35768 | train_auc: 0.9352  | valid_auc: 0.92861 |  0:00:52s
# epoch 28 | loss: 0.35787 | train_auc: 0.93504 | valid_auc: 0.9302  |  0:00:54s
# epoch 29 | loss: 0.3569  | train_auc: 0.93601 | valid_auc: 0.9307  |  0:00:56s
# epoch 30 | loss: 0.35478 | train_auc: 0.93645 | valid_auc: 0.92846 |  0:00:58s
# epoch 31 | loss: 0.35714 | train_auc: 0.93707 | valid_auc: 0.92878 |  0:00:59s
# epoch 32 | loss: 0.3508  | train_auc: 0.93707 | valid_auc: 0.92726 |  0:01:01s
# epoch 33 | loss: 0.35095 | train_auc: 0.93713 | valid_auc: 0.92728 |  0:01:03s
# epoch 34 | loss: 0.35306 | train_auc: 0.93729 | valid_auc: 0.92786 |  0:01:05s
# epoch 35 | loss: 0.3509  | train_auc: 0.93818 | valid_auc: 0.92784 |  0:01:07s
# epoch 36 | loss: 0.3502  | train_auc: 0.93777 | valid_auc: 0.92787 |  0:01:09s
# epoch 37 | loss: 0.35226 | train_auc: 0.93787 | valid_auc: 0.92712 |  0:01:11s
# epoch 38 | loss: 0.35518 | train_auc: 0.93786 | valid_auc: 0.92712 |  0:01:13s
# epoch 39 | loss: 0.34995 | train_auc: 0.93797 | valid_auc: 0.92713 |  0:01:14s
# epoch 40 | loss: 0.34621 | train_auc: 0.93842 | valid_auc: 0.92706 |  0:01:16s
# epoch 41 | loss: 0.34746 | train_auc: 0.93921 | valid_auc: 0.92486 |  0:01:19s
# epoch 42 | loss: 0.35166 | train_auc: 0.93817 | valid_auc: 0.92652 |  0:01:21s
# epoch 43 | loss: 0.35697 | train_auc: 0.93905 | valid_auc: 0.92719 |  0:01:22s
# epoch 44 | loss: 0.34486 | train_auc: 0.94048 | valid_auc: 0.92658 |  0:01:24s
# epoch 45 | loss: 0.34847 | train_auc: 0.9409  | valid_auc: 0.92708 |  0:01:26s
# epoch 46 | loss: 0.34568 | train_auc: 0.93984 | valid_auc: 0.92447 |  0:01:28s
# epoch 47 | loss: 0.34489 | train_auc: 0.94077 | valid_auc: 0.92726 |  0:01:30s
# epoch 48 | loss: 0.35039 | train_auc: 0.93991 | valid_auc: 0.92418 |  0:01:32s
# epoch 49 | loss: 0.33447 | train_auc: 0.94086 | valid_auc: 0.9243  |  0:01:34s
#
# Early stopping occurred at epoch 49 with best_epoch = 29 and best_valid_auc = 0.9307
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 0.58039 | train_auc: 0.81603 | valid_auc: 0.82541 |  0:00:01s
# epoch 1  | loss: 0.47431 | train_auc: 0.86123 | valid_auc: 0.86594 |  0:00:03s
# epoch 2  | loss: 0.45242 | train_auc: 0.88246 | valid_auc: 0.88437 |  0:00:05s
# epoch 3  | loss: 0.43115 | train_auc: 0.89496 | valid_auc: 0.8941  |  0:00:07s
# epoch 4  | loss: 0.42419 | train_auc: 0.90402 | valid_auc: 0.9033  |  0:00:09s
# epoch 5  | loss: 0.41078 | train_auc: 0.90977 | valid_auc: 0.91151 |  0:00:11s
# epoch 6  | loss: 0.39628 | train_auc: 0.91397 | valid_auc: 0.91681 |  0:00:13s
# epoch 7  | loss: 0.39185 | train_auc: 0.91789 | valid_auc: 0.9221  |  0:00:15s
# epoch 8  | loss: 0.3884  | train_auc: 0.92078 | valid_auc: 0.92504 |  0:00:16s
# epoch 9  | loss: 0.38239 | train_auc: 0.92131 | valid_auc: 0.92382 |  0:00:18s
# epoch 10 | loss: 0.37835 | train_auc: 0.92278 | valid_auc: 0.92278 |  0:00:20s
# epoch 11 | loss: 0.37798 | train_auc: 0.926   | valid_auc: 0.92547 |  0:00:22s
# epoch 12 | loss: 0.37593 | train_auc: 0.92697 | valid_auc: 0.92635 |  0:00:24s
# epoch 13 | loss: 0.36354 | train_auc: 0.92665 | valid_auc: 0.92803 |  0:00:26s
# epoch 14 | loss: 0.36719 | train_auc: 0.92853 | valid_auc: 0.92573 |  0:00:28s
# epoch 15 | loss: 0.36773 | train_auc: 0.92947 | valid_auc: 0.92601 |  0:00:29s
# epoch 16 | loss: 0.35922 | train_auc: 0.92965 | valid_auc: 0.92726 |  0:00:31s
# epoch 17 | loss: 0.3629  | train_auc: 0.93076 | valid_auc: 0.92789 |  0:00:34s
# epoch 18 | loss: 0.36588 | train_auc: 0.93158 | valid_auc: 0.92813 |  0:00:35s
# epoch 19 | loss: 0.36606 | train_auc: 0.93175 | valid_auc: 0.9277  |  0:00:37s
# epoch 20 | loss: 0.36084 | train_auc: 0.93214 | valid_auc: 0.92787 |  0:00:39s
# epoch 21 | loss: 0.35925 | train_auc: 0.9327  | valid_auc: 0.9274  |  0:00:40s
# epoch 22 | loss: 0.35809 | train_auc: 0.93349 | valid_auc: 0.9279  |  0:00:42s
# epoch 23 | loss: 0.36347 | train_auc: 0.935   | valid_auc: 0.92762 |  0:00:44s
# epoch 24 | loss: 0.3574  | train_auc: 0.93503 | valid_auc: 0.92718 |  0:00:46s
# epoch 25 | loss: 0.35662 | train_auc: 0.93494 | valid_auc: 0.92735 |  0:00:48s
# epoch 26 | loss: 0.35422 | train_auc: 0.93577 | valid_auc: 0.92946 |  0:00:50s
# epoch 27 | loss: 0.35768 | train_auc: 0.9352  | valid_auc: 0.92861 |  0:00:52s
# epoch 28 | loss: 0.35787 | train_auc: 0.93504 | valid_auc: 0.9302  |  0:00:53s
# epoch 29 | loss: 0.3569  | train_auc: 0.93601 | valid_auc: 0.9307  |  0:00:55s
# epoch 30 | loss: 0.35478 | train_auc: 0.93645 | valid_auc: 0.92846 |  0:00:58s
# epoch 31 | loss: 0.35714 | train_auc: 0.93707 | valid_auc: 0.92878 |  0:00:59s
# epoch 32 | loss: 0.3508  | train_auc: 0.93707 | valid_auc: 0.92726 |  0:01:01s
# epoch 33 | loss: 0.35095 | train_auc: 0.93713 | valid_auc: 0.92728 |  0:01:03s
# epoch 34 | loss: 0.35306 | train_auc: 0.93729 | valid_auc: 0.92786 |  0:01:05s
# epoch 35 | loss: 0.3509  | train_auc: 0.93818 | valid_auc: 0.92784 |  0:01:06s
# epoch 36 | loss: 0.3502  | train_auc: 0.93777 | valid_auc: 0.92787 |  0:01:08s
# epoch 37 | loss: 0.35226 | train_auc: 0.93787 | valid_auc: 0.92712 |  0:01:11s
# epoch 38 | loss: 0.35518 | train_auc: 0.93786 | valid_auc: 0.92712 |  0:01:12s
# epoch 39 | loss: 0.34995 | train_auc: 0.93797 | valid_auc: 0.92713 |  0:01:14s
# epoch 40 | loss: 0.34621 | train_auc: 0.93842 | valid_auc: 0.92706 |  0:01:16s
# epoch 41 | loss: 0.34746 | train_auc: 0.93921 | valid_auc: 0.92486 |  0:01:18s
# epoch 42 | loss: 0.35166 | train_auc: 0.93817 | valid_auc: 0.92652 |  0:01:19s
# epoch 43 | loss: 0.35697 | train_auc: 0.93905 | valid_auc: 0.92719 |  0:01:22s
# epoch 44 | loss: 0.34486 | train_auc: 0.94048 | valid_auc: 0.92658 |  0:01:24s
# epoch 45 | loss: 0.34847 | train_auc: 0.9409  | valid_auc: 0.92708 |  0:01:25s
# epoch 46 | loss: 0.34568 | train_auc: 0.93984 | valid_auc: 0.92447 |  0:01:27s
# epoch 47 | loss: 0.34489 | train_auc: 0.94077 | valid_auc: 0.92726 |  0:01:29s
# epoch 48 | loss: 0.35039 | train_auc: 0.93991 | valid_auc: 0.92418 |  0:01:31s
# epoch 49 | loss: 0.33447 | train_auc: 0.94086 | valid_auc: 0.9243  |  0:01:32s
#
# Early stopping occurred at epoch 49 with best_epoch = 29 and best_valid_auc = 0.9307
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 0.58039 | train_auc: 0.81603 | valid_auc: 0.82541 |  0:00:02s
# epoch 1  | loss: 0.47431 | train_auc: 0.86123 | valid_auc: 0.86594 |  0:00:03s
# epoch 2  | loss: 0.45242 | train_auc: 0.88246 | valid_auc: 0.88437 |  0:00:05s
# epoch 3  | loss: 0.43115 | train_auc: 0.89496 | valid_auc: 0.8941  |  0:00:07s
# epoch 4  | loss: 0.42419 | train_auc: 0.90402 | valid_auc: 0.9033  |  0:00:09s
# epoch 5  | loss: 0.41078 | train_auc: 0.90977 | valid_auc: 0.91151 |  0:00:10s
# epoch 6  | loss: 0.39628 | train_auc: 0.91397 | valid_auc: 0.91681 |  0:00:13s
# epoch 7  | loss: 0.39185 | train_auc: 0.91789 | valid_auc: 0.9221  |  0:00:15s
# epoch 8  | loss: 0.3884  | train_auc: 0.92078 | valid_auc: 0.92504 |  0:00:17s
# epoch 9  | loss: 0.38239 | train_auc: 0.92131 | valid_auc: 0.92382 |  0:00:18s
# epoch 10 | loss: 0.37835 | train_auc: 0.92278 | valid_auc: 0.92278 |  0:00:20s
# epoch 11 | loss: 0.37798 | train_auc: 0.926   | valid_auc: 0.92547 |  0:00:22s
# epoch 12 | loss: 0.37593 | train_auc: 0.92697 | valid_auc: 0.92635 |  0:00:24s
# epoch 13 | loss: 0.36354 | train_auc: 0.92665 | valid_auc: 0.92803 |  0:00:26s
# epoch 14 | loss: 0.36719 | train_auc: 0.92853 | valid_auc: 0.92573 |  0:00:28s
# epoch 15 | loss: 0.36773 | train_auc: 0.92947 | valid_auc: 0.92601 |  0:00:29s
# epoch 16 | loss: 0.35922 | train_auc: 0.92965 | valid_auc: 0.92726 |  0:00:31s
# epoch 17 | loss: 0.3629  | train_auc: 0.93076 | valid_auc: 0.92789 |  0:00:33s
# epoch 18 | loss: 0.36588 | train_auc: 0.93158 | valid_auc: 0.92813 |  0:00:35s
# epoch 19 | loss: 0.36606 | train_auc: 0.93175 | valid_auc: 0.9277  |  0:00:37s
# epoch 20 | loss: 0.36084 | train_auc: 0.93214 | valid_auc: 0.92787 |  0:00:39s
# epoch 21 | loss: 0.35925 | train_auc: 0.9327  | valid_auc: 0.9274  |  0:00:41s
# epoch 22 | loss: 0.35809 | train_auc: 0.93349 | valid_auc: 0.9279  |  0:00:43s
# epoch 23 | loss: 0.36347 | train_auc: 0.935   | valid_auc: 0.92762 |  0:00:44s
# epoch 24 | loss: 0.3574  | train_auc: 0.93503 | valid_auc: 0.92718 |  0:00:46s
# epoch 25 | loss: 0.35662 | train_auc: 0.93494 | valid_auc: 0.92735 |  0:00:48s
# epoch 26 | loss: 0.35422 | train_auc: 0.93577 | valid_auc: 0.92946 |  0:00:50s
# epoch 27 | loss: 0.35768 | train_auc: 0.9352  | valid_auc: 0.92861 |  0:00:52s
# epoch 28 | loss: 0.35787 | train_auc: 0.93504 | valid_auc: 0.9302  |  0:00:54s
# epoch 29 | loss: 0.3569  | train_auc: 0.93601 | valid_auc: 0.9307  |  0:00:56s
# epoch 30 | loss: 0.35478 | train_auc: 0.93645 | valid_auc: 0.92846 |  0:00:57s
# epoch 31 | loss: 0.35714 | train_auc: 0.93707 | valid_auc: 0.92878 |  0:00:59s
# epoch 32 | loss: 0.3508  | train_auc: 0.93707 | valid_auc: 0.92726 |  0:01:02s
# epoch 33 | loss: 0.35095 | train_auc: 0.93713 | valid_auc: 0.92728 |  0:01:04s
# epoch 34 | loss: 0.35306 | train_auc: 0.93729 | valid_auc: 0.92786 |  0:01:05s
# epoch 35 | loss: 0.3509  | train_auc: 0.93818 | valid_auc: 0.92784 |  0:01:07s
# epoch 36 | loss: 0.3502  | train_auc: 0.93777 | valid_auc: 0.92787 |  0:01:09s
# epoch 37 | loss: 0.35226 | train_auc: 0.93787 | valid_auc: 0.92712 |  0:01:11s
# epoch 38 | loss: 0.35518 | train_auc: 0.93786 | valid_auc: 0.92712 |  0:01:13s
# epoch 39 | loss: 0.34995 | train_auc: 0.93797 | valid_auc: 0.92713 |  0:01:15s
# epoch 40 | loss: 0.34621 | train_auc: 0.93842 | valid_auc: 0.92706 |  0:01:17s
# epoch 41 | loss: 0.34746 | train_auc: 0.93921 | valid_auc: 0.92486 |  0:01:19s
# epoch 42 | loss: 0.35166 | train_auc: 0.93817 | valid_auc: 0.92652 |  0:01:20s
# epoch 43 | loss: 0.35697 | train_auc: 0.93905 | valid_auc: 0.92719 |  0:01:22s
# epoch 44 | loss: 0.34486 | train_auc: 0.94048 | valid_auc: 0.92658 |  0:01:24s
# epoch 45 | loss: 0.34847 | train_auc: 0.9409  | valid_auc: 0.92708 |  0:01:26s
# epoch 46 | loss: 0.34568 | train_auc: 0.93984 | valid_auc: 0.92447 |  0:01:28s
# epoch 47 | loss: 0.34489 | train_auc: 0.94077 | valid_auc: 0.92726 |  0:01:30s
# epoch 48 | loss: 0.35039 | train_auc: 0.93991 | valid_auc: 0.92418 |  0:01:31s
# epoch 49 | loss: 0.33447 | train_auc: 0.94086 | valid_auc: 0.9243  |  0:01:33s
#
# Early stopping occurred at epoch 49 with best_epoch = 29 and best_valid_auc = 0.9307
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
# plot losses
plt.plot(clf.history['loss'])

# %%
# plot auc
plt.plot(clf.history['train_auc'])
plt.plot(clf.history['valid_auc'])

# %%
# plot learning rates
plt.plot(clf.history['lr'])

# %% [markdown]
# ## Predictions

# %%
preds = clf.predict_proba(X_test)
test_auc = roc_auc_score(y_score=preds[:,1], y_true=y_test)


preds_valid = clf.predict_proba(X_valid)
valid_auc = roc_auc_score(y_score=preds_valid[:,1], y_true=y_valid)

print(f"BEST VALID SCORE FOR {dataset_name} : {clf.best_cost}")
print(f"FINAL TEST SCORE FOR {dataset_name} : {test_auc}")
# Out:
# BEST VALID SCORE FOR census-income : 0.9306975262472645
# FINAL TEST SCORE FOR census-income : 0.92624806447162

# %%
# check that best weights are used
assert np.isclose(valid_auc, np.max(clf.history['valid_auc']), atol=1e-6)

# %%
clf.predict(X_test)
# Out:
# array(['not_wealthy', 'not_wealthy', 'wealthy', ..., 'not_wealthy',
#        'wealthy', 'wealthy'], dtype='<U11')

# %% [markdown]
# # Save and load Model

# %%
# save tabnet model
saving_path_name = "./tabnet_model_test_1"
saved_filepath = clf.save_model(saving_path_name)
# Out:
# Successfully saved model at ./tabnet_model_test_1.zip

# %%
# define new model with basic parameters and load state dict weights
loaded_clf = TabNetClassifier()
loaded_clf.load_model(saved_filepath)
# Out:
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %%
loaded_preds = loaded_clf.predict_proba(X_test)
loaded_test_auc = roc_auc_score(y_score=loaded_preds[:,1], y_true=y_test)

print(f"FINAL TEST SCORE FOR {dataset_name} : {loaded_test_auc}")
# Out:
# FINAL TEST SCORE FOR census-income : 0.92624806447162

# %%
assert(test_auc == loaded_test_auc)

# %%
loaded_clf.predict(X_test)
# Out:
# array(['not_wealthy', 'not_wealthy', 'wealthy', ..., 'not_wealthy',
#        'wealthy', 'wealthy'], dtype='<U11')

# %% [markdown]
# # Global explainability : feat importance summing to 1

# %%
clf.feature_importances_
# Out:
# array([0.03504346, 0.03504346, 0.03504346, 0.03070843, 0.11777927,
#        0.32325356, 0.13830008, 0.02580644, 0.05287576, 0.05287576,
#        0.05287576, 0.04380496, 0.05150199, 0.0050876 ])

# %% [markdown]
# # Local explainability and masks

# %%
explain_matrix, masks = clf.explain(X_test)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20,20))


for i in range(3):
    axs[i].imshow(masks[i][:50])
    axs[i].set_title(f"mask {i}")
    axs[i].set_xticklabels(labels = features, rotation=45)
# Out:
# <ipython-input-35-cdd8a56390e0>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(labels = features, rotation=45)
# <ipython-input-35-cdd8a56390e0>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(labels = features, rotation=45)
# <ipython-input-35-cdd8a56390e0>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(labels = features, rotation=45)

# %% [markdown]
# # XGB

# %%
y_train = (y_train == 'wealthy')*1
y_valid = (y_valid == 'wealthy')*1
y_test = (y_test == 'wealthy')*1

# %%
from xgboost import XGBClassifier

clf_xgb = XGBClassifier(max_depth=8,
    learning_rate=0.1,
    n_estimators=1000,
    verbosity=0,
    silent=None,
    objective='binary:logistic',
    booster='gbtree',
    n_jobs=-1,
    nthread=None,
    gamma=0,
    min_child_weight=1,
    max_delta_step=0,
    subsample=0.7,
    colsample_bytree=1,
    colsample_bylevel=1,
    colsample_bynode=1,
    reg_alpha=0,
    reg_lambda=1,
    scale_pos_weight=1,
    base_score=0.5,
    random_state=0,
    seed=None,)

clf_xgb.fit(X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=10)
# Out:
# [0]	validation_0-logloss:0.63478
# [10]	validation_0-logloss:0.37938
# [20]	validation_0-logloss:0.31122
# [30]	validation_0-logloss:0.28836
# [40]	validation_0-logloss:0.27925
# [50]	validation_0-logloss:0.27512
# [60]	validation_0-logloss:0.27300
# [70]	validation_0-logloss:0.27144
# [80]	validation_0-logloss:0.27015
# [90]	validation_0-logloss:0.27008
# [100]	validation_0-logloss:0.27083
# [110]	validation_0-logloss:0.27110
# [120]	validation_0-logloss:0.27183
# [130]	validation_0-logloss:0.27286
# [140]	validation_0-logloss:0.27349
# [150]	validation_0-logloss:0.27453
# [160]	validation_0-logloss:0.27579
# [170]	validation_0-logloss:0.27573
# [180]	validation_0-logloss:0.27717
# [190]	validation_0-logloss:0.27819
# [200]	validation_0-logloss:0.27875
# [210]	validation_0-logloss:0.27939
# [220]	validation_0-logloss:0.27994
# [230]	validation_0-logloss:0.28124
# [240]	validation_0-logloss:0.28267
# [250]	validation_0-logloss:0.28377
# [260]	validation_0-logloss:0.28448
# [270]	validation_0-logloss:0.28550
# [280]	validation_0-logloss:0.28635
# [290]	validation_0-logloss:0.28773
# [300]	validation_0-logloss:0.28824
# [310]	validation_0-logloss:0.28906
# [320]	validation_0-logloss:0.28957
# [330]	validation_0-logloss:0.29074
# [340]	validation_0-logloss:0.29213
# [350]	validation_0-logloss:0.29398
# [360]	validation_0-logloss:0.29486
# [370]	validation_0-logloss:0.29572
# [380]	validation_0-logloss:0.29563
# [390]	validation_0-logloss:0.29675
# [400]	validation_0-logloss:0.29846
# [410]	validation_0-logloss:0.29897
# [420]	validation_0-logloss:0.29950
# [430]	validation_0-logloss:0.29984
# [440]	validation_0-logloss:0.30017
# [450]	validation_0-logloss:0.30127
# [460]	validation_0-logloss:0.30240
# [470]	validation_0-logloss:0.30385
# [480]	validation_0-logloss:0.30476
# [490]	validation_0-logloss:0.30625
# [500]	validation_0-logloss:0.30721
# [510]	validation_0-logloss:0.30843
# [520]	validation_0-logloss:0.30968
# [530]	validation_0-logloss:0.31079
# [540]	validation_0-logloss:0.31179
# [550]	validation_0-logloss:0.31342
# [560]	validation_0-logloss:0.31417
# [570]	validation_0-logloss:0.31486
# [580]	validation_0-logloss:0.31617
# [590]	validation_0-logloss:0.31749
# [600]	validation_0-logloss:0.31815
# [610]	validation_0-logloss:0.31985
# [620]	validation_0-logloss:0.32031
# [630]	validation_0-logloss:0.32221
# [640]	validation_0-logloss:0.32317
# [650]	validation_0-logloss:0.32426
# [660]	validation_0-logloss:0.32485
# [670]	validation_0-logloss:0.32566
# [680]	validation_0-logloss:0.32688
# [690]	validation_0-logloss:0.32797
# [700]	validation_0-logloss:0.32952
# [710]	validation_0-logloss:0.33150
# [720]	validation_0-logloss:0.33302
# [730]	validation_0-logloss:0.33372
# [740]	validation_0-logloss:0.33441
# [750]	validation_0-logloss:0.33545
# [760]	validation_0-logloss:0.33650
# [770]	validation_0-logloss:0.33777
# [780]	validation_0-logloss:0.33906
# [790]	validation_0-logloss:0.34020
# [800]	validation_0-logloss:0.34084
# [810]	validation_0-logloss:0.34175
# [820]	validation_0-logloss:0.34301
# [830]	validation_0-logloss:0.34419
# [840]	validation_0-logloss:0.34546
# [850]	validation_0-logloss:0.34700
# [860]	validation_0-logloss:0.34861
# [870]	validation_0-logloss:0.35009
# [880]	validation_0-logloss:0.35080
# [890]	validation_0-logloss:0.35199
# [900]	validation_0-logloss:0.35295
# [910]	validation_0-logloss:0.35390
# [920]	validation_0-logloss:0.35497
# [930]	validation_0-logloss:0.35605
# [940]	validation_0-logloss:0.35749
# [950]	validation_0-logloss:0.35864
# [960]	validation_0-logloss:0.35904
# [970]	validation_0-logloss:0.35997
# [980]	validation_0-logloss:0.36026
# [990]	validation_0-logloss:0.36118
# [999]	validation_0-logloss:0.36208
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=0, max_depth=8,
#               max_leaves=None, min_child_weight=1, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#               n_jobs=-1, nthread=None, num_parallel_tree=None, ...)

# %%
preds = np.array(clf_xgb.predict_proba(X_valid))
valid_auc = roc_auc_score(y_score=preds[:,1], y_true=y_valid)
print(valid_auc)

preds = np.array(clf_xgb.predict_proba(X_test))
test_auc = roc_auc_score(y_score=preds[:,1], y_true=y_test)
print(test_auc)
# Out:
# 0.9110206014656277
# 0.9066786588513054

# %%
end = time.time()

# %%
delta = int(end - start)

# %%
print(delta)
# Out:
# 787
